# %% [markdown]
# ### Inheritance
# * The mechanism of deriving a new class from an old one (existing class)
# such that the new class inherit all the members (variables and methods) of
# old class is  called inheritance or derivation.
#
# ### Super Class and Sub Class
# * The old class is referred to as the Super class and the new one is called the Sub class.
#   * Parent class - Base class or Super class
#   * Child class - Derived class or Sub class
#
# ### Inheritance
# * All classes in python are built from a single super class called object so
# whenever we create a class in python, obejct will become super class for them internally.
# * The main advantage of inheritance is code reusability.
#
# ### Type of Inheritance
# * Single Inheritance
# * Multi-level Inheritance
# * Hierarchical Inheritance
# * Multiple Inheritance

# %% [markdown]
# ### Single Inheritance
# * If a class is derived from one base class (Parent Class), it is called Single Inheritance.

# %%
# Example:
class Father:
      money = 1000  # class variable
    
      def show(self):  # Parent class method
        print("Parent Class Instance Method")
    
      @classmethod   # class method
      def showmoney(cls):
        print("Parent Class Class Method:", cls.money)
    
      @staticmethod   # static method
      def stat():
        a = 10
        print("Parent Class Static Method:", a)

class Son(Father):  # Son class is inherit from Father class
      def disp(self): # Child class method
        print("Child Class Instance Method")

s = Son() # Creating object of Son class to access Father class members
s.disp()  # Calling child class method
s.show()  # Parent class method
s.showmoney() # Parent class method
s.stat()   # Parent class static method
# Out:
# Child Class Instance Method
# Parent Class Instance Method
# Parent Class Class Method: 1000
# Parent Class Static Method: 10

# %% [markdown]
# * We can access Parent class variables and methods using child class object.
# * We can also access Parent class variables and methods using parent class obejct.
# * We can not access Child class variables and methods using parent class object.

# %% [markdown]
# ### Constructor in Inheritance
# * By default, the constructor in the parent class is available to the child class.

# %%
# Example:
class Father:
  def __init__(self):  # constructor
    self.money = 1000   # Instance variable
    print("Parent Class Constructor")

  def show(self):   # Instance method
    print("Parent Class Instance Method")

class Son(Father):  # Son class derived from Father class
  def disp(self):
    print("Child Class Instance Method")

# Creating object of child class
s = Son()  # Creating object will automatically call Father class constructor
print(s.money)   # Accessing Father class instance variable
s.show()  # calling parent class show() instance method
s.disp()   # calling child class disp() instance method
# Out:
# Parent Class Constructor
# 1000
# Parent Class Instance Method
# Child Class Instance Method

# %%
# Constructor Inheritance

class Father:
  def __init__(self, m):  # Constructor with parameter
    self.money = m   # Instance variable
    print("Parent Class Constructor")

  def show(self):
    print("Parent Class Instance Method")

class Son(Father):
  def disp(self):
    print("Child Class Instance Method", self.money+1000) # Accessing Father class instance variable

# Creating object of child class
s = Son(1000)
print(s.money)  # calling Parent class instance variable
s.show()  # calling Parent class method
s.disp()  # calling child class method
# Out:
# Parent Class Constructor
# 1000
# Parent Class Instance Method
# Child Class Instance Method 2000

# %% [markdown]
# ### Constructor Overriding
# #### What will happen if we define constructor in both classes?
# * If we write constructor in the both classes, parent class and child class then the parent class constructor is not available to the child class.
# * In this case only child class constructor is accessible which means child class constructor is replacing parent class constructor.
# * Constructor overriding is used when programmer want to modify the existing behavior of a constructor.

# %%
# Constructor Overriding
class Father:           # Parent class
  def __init__(self):   # Constructor
    self.money = 1000   # Instance variable
    print("Parent Class Constructor")

  def show(self):    # Parent class instance method
    print("Parent Class Instance Method")

class Son(Father):   # Inheriting Son class from Father class
  def __init__(self):  # Constructor
    self.money = 5000  # Child class Instance variable
    self.car = 'BMW'
    print("Child Class Constructor")

  def disp(self): # Child class instance method
    print("Child Class Instance Method")

s = Son() # Creating object of child class
print(s.money)  # This will call child class instance variable
print(s.car)
s.disp()   # calling child class method
s.show()   # calling parent class method
# Out:
# Child Class Constructor
# 5000
# BMW
# Child Class Instance Method
# Parent Class Instance Method

# %%
# Constructor overriding with parameter
# Child class constructor overides the parent class constructor.

class Father:           # Parent class
  def __init__(self, m):
    self.money = m
    print("Parent Class Constructor")

  def show(self):    # Parent class instance method
    print("Parent Class Instance Method")

class Son(Father):
  def __init__(self, r):
    self.money = r
    self.car = 'BMW'
    print("Child Class Constructor")

  def disp(self):
    print("Child Class Instance Method")

s = Son(2000)   # creating object of child class and passing value for r
print(s.money)
print(s.car)
s.disp()
s.show()
# Out:
# Child Class Constructor
# 2000
# BMW
# Child Class Instance Method
# Parent Class Instance Method

# %% [markdown]
# ### Constructor with super() method
# * If we write constructor in the both classes, parent class and child class
# then the parent class constructor is not available to the child class.
# * In this case only child class constructor is accessible which means
# child class constructor is replacing parent class constructor.
# * super() method is used to call parent class constructor or methods from the child class.

# %%
# Example: Constructor with super() method
class Father:
  def __init__(self):
    self.money = 1000
    print("Parent Class Constructor")

  def show(self):
    print("Parent Class Instance Method")

class Son(Father):
  def __init__(self):
    super().__init__()  # calling parent class constructor
    print("Child Class Constructor")

  def disp(self):
    print("Child Class Instance Method", self.money) # using parent class instance variable

s = Son()  # creating child class object
s.disp()   # calling child class method
# Out:
# Parent Class Constructor
# Child Class Constructor
# Child Class Instance Method 1000

# %%
# Constructor (Parameterized) with super() method
class Father:
  def __init__(self, m):
    self.money = m
    print("Parent Class Constructor")

  def show(self):
    print("Parent Class Instance Method")

class Son(Father):
  def __init__(self, m):
    super().__init__(m)  # calling parent class constructor and passing m to parent class constructor
    print("Child Class Constructor")

  def disp(self):
    print("Child Class Instance Method", self.money) # using parent class instance variable

s = Son(1000)  # creating object of Son class and passing value for m of Son class
s.disp()
# Out:
# Parent Class Constructor
# Child Class Constructor
# Child Class Instance Method 1000

# %%
# Constructor (Parameterized) with super() method
class Father:
  def __init__(self, m):
    self.money = m
    print("Parent Class Constructor")

  def show(self):
    print("Parent Class Instance Method")

class Son(Father):
  def __init__(self, m, j):  # m = 1000, j = Python
    super().__init__(m)  # calling parent class constructor and passing m to parent class constructor
    self.job = j
    print("Child Class Constructor")

  def disp(self):
    print("Child Class Instance Method", self.money, "Job:", self.job) # using parent class instance variable

s = Son(1000, 'Python')   # creating object of child class and passing value
s.disp()   # calling child class method
# Out:
# Parent Class Constructor
# Child Class Constructor
# Child Class Instance Method 1000 Job: Python

# %% [markdown]
# ### Multi-level Inheritance
# * In multi-level inheritance, the class inherits the features of another derived class(Child Class).

# %%
# Multilevel Inheritance:
class Father:
   def __init__(self):
     print("Parent Class Constructor")
   def showF(self):
     print("Child Class Constructor")

class Son(Father):
  def __init__(self):
    print("Child Class Constructor")
  def showS(self):
    print("Child Class Method")

class GrandSon(Son):
  def __init__(self):
    super().__init__()  # Calling Son Class Constructor
    print("GrandChild Class Constructor")
  def showG(self):
    print("Grandchild Class Method")

g = GrandSon()  # Creating object of GrandSon Class will automatically call it's own constructor
g.showG()  # calling showG() of GrandSon
g.showF()  # calling showF() of Father
g.showS()  # calling showS() of Son
# Out:
# Child Class Constructor
# GrandChild Class Constructor
# Grandchild Class Method
# Child Class Constructor
# Child Class Method

# %% [markdown]
# ### Hierarchical Inheritance
# * Hierarchical inheritance occurs when multiple child classes inherit from a single parent (base) class.
# * This allows all child classes to reuse common functionality defined in the parent class, while still having their own specific features.

# %%
# Hierarchical Inheritance
class Father:
  def showF(self):
    print("Parent Class Method")

class Son(Father):
  def showS(self):
    print("Child Class Method")

class Daughter(Father):
  def showD(self):
    print("Daughter Class Method")

s = Son()  # Creating Son class object
s.showS()  # Calling Son class method
s.showF()  # Calling parent class method

d = Daughter()  # Creating Daughter class object
d.showD()  # Calling Daughter class method
d.showF()  # Calling Father class method
# Out:
# Child Class Method
# Parent Class Method
# Daughter Class Method
# Parent Class Method

# %%
# Hierarchical Inheritance
class Father:
  def showF(self):
    print("Parent Class Method")

class Son(Father):
  def showS(self):
    print("Child Class Method")

class Daughter(Father):
  def showD(self):
    print("Daughter Class Method")

d = Daughter()
d.showD()
d.showF()
# Out:
# Daughter Class Method
# Parent Class Method

# %%
# Hierarchical Inheritance
class Father:
  def __init__(self):
    print("Parent Class Constructor")
  def showF(self):
    print("Parent Class Method")

class Son(Father):
  def __init__(self):
    super().__init__()   # Calling parent class constructor
    print("Child Class Constructor")
  def showS(self):
    print("Child Class Method")

class Daughter(Father):
  def __init__(self):
    print("Daughter Class Constructor")
  def showD(self):
    print("Daughter Class Method")

s = Son()
# Out:
# Parent Class Constructor
# Child Class Constructor

# %% [markdown]
# ### Multiple Inheritance
# * If a class is derived from more than one parent class, then it is called multiple inheritance.

# %%
# Multiple Inheritance
class Father:
  def __init__(self):
    print("Father class Constructor")
  def showF(self):
    print("Father Class Method")

class Mother:
  def __init__(self):
    print("Mother class Constructor")
  def showM(self):
    print("Mother Class Method")

class Son(Father, Mother):  # Son class is derived from Father and Mother class
  def __init__(self):
    super().__init__()    # Calling parent class constructor, will transfer control to Father class
    print("Son class Constructor")
  def showS(self):
    print("Child Class Method")

s = Son()  # Creating Son class object will automatically call Father class constructor
s.showS()    # Calling Son class method
s.showF()  # Calling Father class method
s.showM()  # Calling Mother class method
# Out:
# Father class Constructor
# Son class Constructor
# Child Class Method
# Father Class Method
# Mother Class Method

# %%
# Multiple Inheritance
# If a class is derived from more than one parent class, then it is called multiple inheritance.

class Father(object):
  def __init__(self):  # 4th, Father class constructor is called
    super().__init__()       # 5th, Calling Parent Class Constructor ie. Object Class but Object class doesn't have any constructor so control transfer to right side ie. Mother Class 
    print("Father class Constructor")  # 9th, this is executed and control transfer to Son Class Constructor
  def showF(self):
    print("Father Class Method")

class Mother(object):
  def __init__(self):  # 6th, Mother Class constructor is called
    super().__init__()      # 7th, Calling Parent Class Constructor ie. Object Class which is already visited so control transfer to next line below it.
    print("Mother class Constructor") # 8th, this is executed and control transfer to Father Class 
  def showM(self):
    print("Mother Class Method")

class Son(Father, Mother):  # Son class is derived from Father and Mother class
  def __init__(self):  # 2nd, Son class constructor is called
    super().__init__()    # 3rd, Calling Parent Class Constructor will call left parent ie. Father class is called.
    print("Son class Constructor")   # 10th, this is executed 
  def showS(self):
    print("Child Class Method")

s = Son()   # 1st, Creating object of Son Class will call Son Class Constructor
# Out:
# Mother class Constructor
# Father class Constructor
# Son class Constructor

# %% [markdown]
# #### Explanation:
# * The search will start from Son. As the object of Son is created, the constructor of Son is called.
# * Son has super().__init__() inside his constructor so its parent class, the one in the left side 'Father' class's constructor is called.
# * Father class also has super().__init__() inside his constructor so its parent 'object' class's constructor is called.
# * Object does not have any constructor so the search will continue down to right hand side class (Mother) of object class so Mother class's constructor is called.
# * As Mother class also has super().__init__() so its parent class 'object' constructor is called but as object class already visited, the search will stop here.

# %% [markdown]
# ### Method Resolution Order (MRO)
# * In the multiple inheritance scenario members of class are searched first in the
# current class. If not found, the search continues into parent class in depth-first,
# left to right manner without searching the same class twice.
# * Search for the child class before going to its parent class.
# * When a class is inherited from several classes, it searches in the order from left to right in the parent classes.
# * It will not visit any class more than once which means a class in the inheritance hierarchy is traversed only once exactly.

# %% [markdown]
# ### Polymorphism
# * Polymorphisms means having many forms.
# * If a variable, object or method perform different behavior according to situation, it is called Polymorphism.
#     * Duck Typing
#     * Operator Overloading
#     * Method Overloading
#     * Method Overriding

# %% [markdown]
# #### Duck Typing
# * Python doesn't care about which class of object it is, if it is an object
# and required behavior is present for that object then it will work.
# * The type of object is distinguished only at runtime. This is called as Duck typing.

# %%
# Example: Duck typing
class Duck:
  def walk(self):
    print("Thapak Thapak Thapak Thapak")

class Horse:
  def walk(self):
    print("Tabdak Tabdak Tabdak Tabdak")

class Cat:
  def talk(self):
    print("Meow Meow")

def myfunction(obj): # obj takes d 
  obj.walk()

d = Duck()  # creating object of Duck class
myfunction(d)  # Calling myfunction() will transfer control to def myfunction() and passing d for obj

h = Horse()  # creating object of Horse class
myfunction(h)

c = Cat()
myfunction(c)     # this will cause error since Cat class has no attribute walk
# Out:
# Thapak Thapak Thapak Thapak
# Tabdak Tabdak Tabdak Tabdak
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 24
#      21 myfunction(h)
#      23 c = Cat()
# ---> 24 myfunction(c)
#
# Cell In[2], line 15, in myfunction(obj)
#      14 def myfunction(obj): # obj takes d
# ---> 15   obj.walk()
#
# AttributeError: 'Cat' object has no attribute 'walk'

# %% [markdown]
# ### Strong Typing
# * We can check whether the object passed to the method has the method being invoked or not.
# * hasattr() function is used to check whether the object has a method or not.
# * Where attribute can be a method or variable. If it is found in the object then this method returns True else False.

# %%
class Duck:
  def walk(self):
    print("Thapak Thapak Thapak Thapak")

class Horse:
  def walk(self):
    print("Tabdak Tabdak Tabdak Tabdak")

class Cat:
  def talk(self):
    print("Meow Meow")

def myfunction(obj): # obj takes object of Duck class ie. d as argument
  if hasattr(obj, 'walk'):  # checks whether obj is walk or not
    obj.walk()
  if hasattr(obj, 'talk'): # we can also use elif instead of if
    obj.talk()

d = Duck()     # Creating object of Duck class
myfunction(d)  # calling function will transfer control to def myfunction()

h = Horse()  # Creating object of Horse class
myfunction(h) # calling function will transfer control to def myfunction()

c = Cat()
myfunction(c)   # this doesn't cause error
# Out:
# Thapak Thapak Thapak Thapak
# Tabdak Tabdak Tabdak Tabdak
# Meow Meow

# %% [markdown]
# ### Method Overloading
# * When more than one method with the same name is defined in the same class, it is known as method Overloading.
# * In Python, If a method is written such that it can perform more than one task, it is called method Overloading.

# %%
class Myclass:
   def sum(self, a=None, b=None, c=None):
      if a!=None and b!=None and c!=None:
        s = a+b+c
      elif a!=None and b!=None:
        s= a*b
      else:
        s= 'Provide at least two numbers'
      return s

obj = Myclass()
print(obj.sum(10, 20, 30))
# print(obj.sum(15,25))
# print(obj.sum())
# Out:
# 60

# %% [markdown]
# ### Method Overriding (similar to constructor overriding)
# * If we write method in the both classes, parent class and child class
# then the parent class's method is not available to the child class.
# * In this case only child class's method is accessible which means child class's
# method is replacing parent class's method.
# * Method overriding is used when programmer want to modify the existing behavior of a Method.

# %%
# Method Overriding
class Add:  # parent class
  def result(self, a, b):     # result function
    print("Addition:", a+b)

class Multi(Add): # inheriting from Add class
  def result(self, a, b):   # result function same as parent class method
    print("Multiplication:", a*b)

# Here, parent class method is overriden by child class method

# %%
# Method Overriding

class Add:
  def result(self, a, b):
    print("Addition:", a+b)

class Multi(Add):
  pass

m = Multi()
m.result(10, 20) # searches result() method in child but if it does not found then search on parent class
# Out:
# Addition: 30

# %% [markdown]
# ### Method with super() Method
# * If we write method in the both classes, parent class and child class then the parent
# class's method is not available to the child class.
# * In this case only child class's method is accessible which means child class's method is replacing parent class's method.
# super() method is used to call parent class's constructor or methods from the child class.
#
# * Syntax: super().methodName()

# %%
class Add:
  def result(self, x, y):
    print("Addition:", x+y)

class Multi(Add):
  def result(self, a, b): # 10 goes a and 20 goes to b of parent class result method
    super().result(30, 50)  # Calling parent class method and passing value for x=30 and y=50
    print("Multiplication:", a*b)

m = Multi()
m.result(10, 20) # Calling child class method and passing value for a=10 and b=20
# Out:
# Addition: 80
# Multiplication: 200

# %%
 # Operator Overloading
# If any operator performs additional actions other than what it is meant for, it is called operator overloading.
class A:
  def __init__(self, x): # constructor
    self.x = x # instance variable
      
  def __add__(self, other):
    return self.x + other.x

class B:
  def __init__(self, x):  # constructor
    self.x = x # instance variable 

a = A(100)  # Creating object of class A and passing value for x
b = B(200)

print(a+b)   # Behind the scene: A.__add__(self, other), A.__Add__(a, b) happens

# More more info: https://python-course.eu/oop/magic-methods.php
# This double underscore method is also called Dunder methods.
# Out:
# 300

# %%
print(10+20)  # This is same as below
print(int.__add__(10,20))  # Behind the scene this happens

print("Hello"+"World")  # This is same as below
print(str.__add__('Hello', 'World'))  # Behind the scene this happens
# Out:
# 30
# 30
# HelloWorld
# HelloWorld

# %% [markdown]
# ### Abstraction:
# * Abstraction means hiding the internal implementation details and showing only the essential features of an object.
# * In simple words, you know what the object does but you don't know how it does.
# * For example, when you use a mobile phone, you press the button to call someone. Here, you don't know how the internal circuits works. This is an example of abstraction
#
# * Abstraction is achieved using:
#     * Abstract class
#     * Abstract method

# %% [markdown]
# ### Abstract Class:
# * A class derived from ABC class which belongs to abc (Abstract Base Class) module, is known as abstract class.
# * ABC class is known as Meta class which means a class that defines the behavior of other classes. So, we can say, Meta Class ABC defines that the class which is derived from it becomes an abstract class.
# * Abstract class can have abstract method and concrete methods.
# * Abstract class needs to be extended and its method implemented.
# * PVM can not create objects of an abstract class.
#
# ### Abstract method:
# * A abstract method is a method whose action is redefined in the child classes as per the requirement of the object.
# * We can declare a method as abstract method by using @abstractmethod decorator
#
# ### Concrete/Normal method:
# * A concrete method is a method whose action is defined in the abstract class itself.
# * We use abstract class when there are some common feature shared by all the objects as they are.

# %%
# Abstract Class
from abc import ABC, abstractmethod
class Father(ABC):  # Abstract class
  @abstractmethod  # Abstract method/method without body
  def disp(self):
    pass    # No implementation here for abstract class

  def show(self):  # concrete method/method with body
    print("Concrete Method")

class Child(Father):  # Child class
 
  def disp(self):
    print("Child Class")
    print("Defining Abstract Method")

c = Child()  # Creating object of Child class
c.disp()  # Calling Child class method
c.show()  # Calling Parent class method
# Out:
# Child Class
# Defining Abstract Method
# Concrete Method

# %% [markdown]
# * Here, disp() is an abstract method(no implementation) in Parent class.
# * Child class must implement the disp() method, otherwise it will not work.
#
# #### Things to know:
# * Abstract class cannot be instantiated.
# * Abstract method must be implemented in child class.

# %% [markdown]
# ### Rules for creating abstract class and abstract method
# * It is not necessary to declare all methods abstract in a abstract class.
# * Abstract class can have abstract method and concrete methods.
# * If there is any abstract method in a class, that class must be abstract.
# * The abstract methods of an abstract class must be defined in its child class.

# %%
from abc import ABC, abstractmethod
class Father(ABC):  # Abstract class
  @abstractmethod
  def disp(self):   # Abstract method
    pass


  def show(self):   # Concrete method
    print("Concrete Method")

class Child(Father):
  def disp(self):
    print("Child Class")
    print("Defining Abstract Method")

c = Child()
c.disp()
c.show()
# Out:
# Child Class
# Defining Abstract Method
# Concrete Method

# %% [markdown]
# ### When to use Abstract Class
# * We use abstract class when there are some common feature shared by all the objects as they are.

# %%
from abc import ABC, abstractmethod
class DefenceForce(ABC):
  def __init__(self):      # Constructor
    self.id = 101     # common features shared by all objects

  @abstractmethod
  def area(self):
    pass

  def gun(self):
    print("Gun = AK47")

class Army(DefenceForce):
  def area(self):
    print("Army Area = Land", self.id)

class AirForce(DefenceForce):
  def area(self):
    print("AirForce Area = Sky", self.id)

class Navy(DefenceForce):
  def area(self):
    print("Navy Area = Sea", self.id)

a = Army()
af = AirForce()
n = Navy()

a.gun()
a.area()
print()
af.gun()
af.area()
print()
n.gun()
n.area()
# Out:
# Gun = AK47
# Army Area = Land 101
#
# Gun = AK47
# AirForce Area = Sky 101
#
# Gun = AK47
# Navy Area = Sea 101

# %% [markdown]
# ### Interface
# * In Python, The interface concept is not explicitly available, like avaialble in other languages eg. Java
# * In Python, an interface is an abstract class which contains only abstract method but not a single concrete method.
# #### Rules:
# * All methods of an interface is abstract.
# * We cannot create object of interface.
# * If a class is implementing an interface it has to define all the methods given in that interface.
# * If a class does not implement all the methods declared in the interface, the class must be declared abstract.
#
# #### When to use Interface
# * We use interface when all the features need to be implemented differently for different objects.

# %%
# Interface
from abc import ABC, abstractmethod
class Father(ABC):  # Abstract class
  @abstractmethod
  def disp1(self):
    pass

  @abstractmethod
  def disp2(self):
    pass

class Child(Father):
  def disp1(self):
    print("Child Class")
    print("Disp 1 Abstract Method")

class Grandchild(Child):
  def disp2(self):
    print("Grandchild Class")
    print("Disp 2 Abstract Method")

gc = Grandchild()
gc.disp1()
gc.disp2()
# Out:
# Child Class
# Disp 1 Abstract Method
# Grandchild Class
# Disp 2 Abstract Method

# %% [markdown]
# ### Abstract class vs Interface
# * An abstract class can have abstract methods as well as concrete methods, but all methods of an interface are abstract.
# * We use abstract class when there are some common feature shared by all the objects as they are while we use interface if all the feature need to be implemented differently for different objects.
# * Interface are slow when compared to abstract class.

# %% [markdown]
# ### Polymorphism:
# * Polymorphism allows methods in different classes to share the same name but perform distinct tasks.
# * This is achieved through inheritance and interface design.

# %%
# Example:
class Shape:
    def area(self):
        return "Undefined"

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

shapes = [Rectangle(2, 3), Circle(5)]
for shape in shapes:
    print(f"Area: {shape.area()}")
# Out:
# Area: 6
# Area: 78.5

# %% [markdown]
# ##### Explanation:
# * The code showcases polymorphism using a parent class Shape and child classes Rectangle and Circle.
# * Parent Class Shape: Contains a generic area method returning "Undefined", acting as a placeholder for derived classes to override.
# * Child Class Rectangle: Initializes length and width via the __init__ constructor. Overrides the area method to return the rectangle's area as length * width.
# * Child Class Circle: Initializes radius via the __init__ constructor. Overrides the area method to return the circle's area as 3.14 * radius^2.
# * Polymorphic Behavior: A list of shape objects (Rectangle and Circle) is created. A for loop iterates through the list, calling the area method on each object. The method executed is determined by the object's type, showcasing polymorphism.

# %% [markdown]
# ### Types of Polymorphism:
# #### Compile-time Polymorphism
# * Found in statically typed languages like Java or C++, where the behavior of a function or operator is resolved during the program's compilation phase.
# * Examples include method overloading and operator overloading, where multiple functions or operators can share the same name but perform different tasks based on the context.
# * In Python, which is dynamically typed, compile-time polymorphism is not natively supported. Instead, Python uses techniques like dynamic typing and duck typing to achieve similar flexibility.

# %% [markdown]
# #### Runtime Polymorphism
# * Occurs when the behavior of a method is determined at runtime based on the type of the object.
# * In Python, this is achieved through method overriding: a child class can redefine a method from its parent class to provide its own specific implementation.
# * Python's dynamic nature allows it to excel at runtime polymorphism, enabling flexible and adaptable code.

# %%
# Example:
class Animal:
    def sound(self):
        return "Some generic sound"

class Dog(Animal):
    def sound(self):
        return "Dog Bark"

class Cat(Animal):
    def sound(self):
        return "Cat Meow"

# Polymorphic behavior
animals = [Dog(), Cat(), Animal()]
for animal in animals:
    print(animal.sound())  # Calls the overridden method based on the object type
# Out:
# Dog Bark
# Cat Meow
# Some generic sound

# %% [markdown]
# * Explanation: Here, the sound method behaves differently depending on whether the object is a Dog, Cat or Animal and this decision happens at runtime.
# * This dynamic nature makes Python particularly powerful for runtime polymorphism.

# %% [markdown]
# ### Inheritance Class Polymorphism
# * Inheritance-based polymorphism occurs when a subclass overrides a method from its parent class, providing a specific implementation.
# * This process of re-implementing a method in the child class is known as Method Overriding.

# %%
class Animal:
    def sound(self):
        return "Some generic animal sound"

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

# %% [markdown]
# ##### Explanation:
# * Class Animal: Acts as the base (parent) class. Contains a method sound that provides a default behavior, returning "Some generic animal sound". This serves as a generic representation of the sound method for all animals.
# * Class Dog: Inherits from the Animal class. Overrides the sound method to return "Bark", a behavior specific to dogs. This demonstrates method overriding, where the subclass modifies the implementation of the parent class’s method.
# * Class Cat: Inherits from the Animal class. Overrides the sound method to return "Meow", a behavior specific to cats. Like Dog, this also demonstrates method overriding

# %% [markdown]
# ### Method Overloading in Python:
# * In many programming languages like C++ or Java, you can define multiple methods with the same name but different parameter lists. This concept is called method overloading.
# * Python does not support method overloading by default. If you define multiple methods with the same name, only the latest definition will be used.

# %%
def product(a, b):
    p = a * b
    print(p)

def product(a, b, c):
    p = a * b*c
    print(p)

product(4, 5, 5)
# Out:
# 100

# %% [markdown]
# * The above example clarifies that Python doesn't support method overloading by default, however, it offers several techniques to simulate method overloading.

# %% [markdown]
# #### 1. Using Variable Arguments (*args)
# * In this approach, we use variable-length arguments to accept any number of arguments and handle them inside the function.

# %%
def add(datatype, *args):
    if datatype == 'int':
        res = 0
    elif datatype == 'str':
        res = ''
    
    for item in args:
        res += item   # res = res + item

    print(res)


add('int', 5, 6)
add('str', 'Hi ', 'Geeks')
# Out:
# 11
# Hi Geeks

# %% [markdown]
# ##### Explanation:
# * The first argument specifies the data type (int or str).
# * *args allows passing a variable number of additional arguments.
# * Function uses a loop to add numbers or concatenate strings based on the data type.
# * This simulates method overloading by processing the arguments dynamically.

# %% [markdown]
# #### 2. Using Default Arguments (None as default value)

# %%
def add(a=None, b=None):
    if a is not None and b is None:
        print(a)
    else:
        print(a + b)
        
add(2)
add(2, 3)
# Out:
# 2
# 5

# %% [markdown]
# ##### Explanation:
# * The first parameter of  "add" method is set to None. This will give us the option to call it with or without a parameter.
# #### When we pass arguments to the add method:
# * Conditional statements check how many arguments were provided.
# * If only a is provided, it prints a.
# * If both a and b are provided, it prints their sum.

# %% [markdown]
# #### 3. Using Multiple Dispatch
# * Python's multipledispatch library allows true method overloading by dispatching functions based on parameter types and counts.

# %%
from multipledispatch import dispatch

@dispatch(int, int)
def product(first, second):
    result = first * second
    print(result)

@dispatch(int, int, int)
def product(first, second, third):
    result = first * second * third
    print(result)

@dispatch(float, float, float)
def product(first, second, third):
    result = first * second * third
    print(result)

product(2, 3)
product(2, 3, 2)
product(2.2, 3.4, 2.3)
# Out:
# 6
# 12
# 17.204

# %% [markdown]
# ##### Explanation:
# * @dispatch decorator handles method overloading cleanly.
# * Separate functions are created for different argument signatures.
# * Based on the number and type of arguments, the correct version is called automatically.
# * This method is closest to true method overloading in Python.

# %% [markdown]
# ### Operator Overloading in Python:
# * Operator Overloading means giving extended meaning beyond their predefined operational meaning. For example operator + is used to add two integers as well as join two strings and merge two lists.
# * It is achievable because '+' operator is overloaded by int class and str class.

# %%
# Python program to show use of
# + operator for different purposes.

# add two integers 
print(1 + 2)

# concatenate two strings
print("Hello"+"World") 

# Product two numbers
print(3 * 4)

# Repeat the String
print("Deerwalk"*4)
# Out:
# 3
# HelloWorld
# 12
# DeerwalkDeerwalkDeerwalkDeerwalk

# %% [markdown]
# ### Encapsulation in Python:
# * In Python, encapsulation refers to the bundling/binding of data (variables) and methods (functions) that operate on the data into a single unit, typically a class.
# * It also restricts direct access to some components, which helps protect the integrity of the data and ensures proper usage.
# * Simply, Encapsulation is protecting the data(variables & methods) together and restricting the direct access to it.

# %% [markdown]
# * Encapsulation means hiding internal details of a class and only exposing what’s necessary. It helps to protect important data from being changed directly and keeps the code secure and organized.
# * This Provides better control over data.
# * This Prevents accidental modification of data.

# %% [markdown]
# ##### Why do we need Encapsulation?
# * Protects data from unauthorized access and accidental modification.
# * Controls data updates using getter/setter methods with validation.
# * Enhances modularity by hiding internal implementation details.

# %% [markdown]
# #### Example of Encapsulation:
# * Encapsulation in Python is like having a bank account system where your account balance (data) is kept private. You can't directly change your balance by accessing the account database. Instead, the bank provides you with methods (functions) like deposit and withdraw to modify your balance safely.
# * Private Data (Balance): Your balance is stored securely. Direct access from outside is not allowed, ensuring the data is protected from unauthorized changes.
# * Public Methods (Deposit and Withdraw): These are the only ways to modify your balance. They check if your requests (like withdrawing money) follow the rules (e.g., you have enough balance) before allowing changes.

# %% [markdown]
# #### Python achieves encapsulation through public, protected and private attributes.

# %% [markdown]
# #### Public Members:
# * Public members are accessible from anywhere, both inside and outside the class.

# %%
class Public:
    def __init__(self):
        self.name = "John"  # Public attribute/variable

    def display_name(self):
        print(self.name)  # Public method

obj = Public()
obj.display_name()  # Accessible
print(obj.name)  # Accessible
# Out:
# John
# John

# %% [markdown]
# ##### Explanation:
# * Public Attribute (name): This attribute is declared without any underscore prefixes. It is accessible from anywhere, both inside and outside of the class.
# * Public Method (display_name): This method is also accessible from any part of the code. It directly accesses the public attribute and prints its value.
# * Object (obj): An instance of Public class is created, and the display_name method is called, demonstrating how public attributes and methods can be accessed directly.

# %% [markdown]
# #### Protected members:
# * Protected members are identified with a single underscore (_). They are meant to be accessed only within the class or its subclasses.

# %%
class Protected:
    def __init__(self):
        self._age = 30  # Protected attribute

class Subclass(Protected):
    def display_age(self):
        print(self._age)  # Accessible in subclass

obj = Subclass()
obj.display_age()
# Out:
# 30

# %% [markdown]
# #### Explanation:
# * Protected Attribute (_age): This attribute is prefixed with a single underscore, which by convention, suggests that it should be treated as a protected member. It's not enforced by Python but indicates that it should not be accessed outside of this class and its subclasses.
# * Subclass: Here, a subclass inherits from Protected. Within this subclass, we can still access the protected attribute _age.
# * Method (display_age): This method within the subclass accesses the protected attribute and prints its value. This shows that protected members can be accessed within the class and its subclasses.

# %% [markdown]
# ### Private members:
# * Private members are identified with a double underscore (__) and cannot be accessed directly from outside the class.
# * They are used to restrict access and protect internal data.

# %%
class Private:
    def __init__(self):
        self.__salary = 50000  # Private attribute

    def salary(self):
        return self.__salary  # Access through public method

obj = Private() # creating object

print(obj.salary())  # Works

print(obj.__salary)  # Raises AttributeError
# Out:
# 50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 11
#       8 obj = Private() # creating object
#      10 print(obj.salary())  # Works
# ---> 11 print(obj.__salary)
#
# AttributeError: 'Private' object has no attribute '__salary'

# %% [markdown]
# #### Explanation:
# * Private Attribute (__salary): This attribute is prefixed with two underscores, which makes it a private member. Python enforces privacy by name mangling, which means it renames the attribute in a way that makes it hard to access from outside the class.
# * Method (salary): This public method provides the only way to access the private attribute from outside the class. It safely returns the value of __salary.
# * Direct Access Attempt: Trying to access the private attribute directly (obj.__salary) will result in an AttributeError, showing that direct access is blocked. This is Python's way of enforcing encapsulation at a language level.

# %% [markdown]
# ### Example-1:

# %%
class BankAccount:
    def __init__(self):
        self.balance = 1000 # public attribute

    def _show_balance(self):
        print(f"Balance: {self.balance}")  # Protected method

    def __update_balance(self, amount):
        self.balance += amount             # Private method

    def deposit(self, amount):
        if amount > 0:
            self.__update_balance(amount)  # Accessing private method internally
            self._show_balance()           # Accessing protected method
        else:
            print("Invalid deposit amount!")
            
account = BankAccount()

account._show_balance()      # Works, but should be treated as internal --> 1000
# account.__update_balance(500)  # Error: private method
account.deposit(500)         # Uses both methods internally   -->1500
# Out:
# Balance: 1000
# Balance: 1500

# %% [markdown]
# ### Explanation:
#
# * _show_balance(): (Protected method) Accessible from outside, but intended for internal or subclass use.
#
# * __update_balance(): (Private method) Only accessible inside class due to name mangling.
#
# * deposit(): Public method that safely uses both private and protected methods.

# %% [markdown]
# ### Example-2:

# %%
class Employee:
    def __init__(self):
        self.__salary = 50000  # Private attribute

    def get_salary(self):    # Getter method
        return self.__salary

    def set_salary(self, amount):   # Setter method
        if amount > 0:
            self.__salary = amount
        else:
            print("Invalid salary amount!")

emp = Employee()
print(emp.get_salary())  # Access salary using getter

emp.set_salary(60000)   # Update salary using setter
print(emp.get_salary())
# Out:
# 50000
# 60000

# %% [markdown]
# ### Explanation:
#
# * __salary is a private attribute, so it can't be accessed directly from outside the class.
# * get_salary() is a getter method that safely returns the current salary.
# * set_salary(amount) is a setter method that updates the salary only if the amount is positive.
# * The object emp uses these methods to access and modify the salary while keeping the data protected.
