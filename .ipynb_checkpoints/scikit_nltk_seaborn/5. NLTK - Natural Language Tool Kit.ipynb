# %% [markdown]
# ### NLTK-NLP
# * Natural Language Processing (NLP) plays an important role in enabling machines to understand and generate human language.
# * It can perform a variety of operations on textual data such as classification, tokenization, stemming, tagging, semantic reasoning etc.

# %% [markdown]
# * Technique to analysis and synthesis of natural language and speech
# * Automatic manipulation of natural language like speech, text by software
# * Concerned with interactions between computer and human (natural) language

# %% [markdown]
# * Installl NLTK library: pip install nltk
# * Accessing Additional Resources: For the usage of additional resources such as resourses of languages other than English - we can run the following in a python script. It has to be done only once when you are running it for the first time in your system.

# %%
import nltk
nltk.download('all')   # To download all the package for NLTK
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\User\AppData\Roaming\nltk_data...
# ...

# %% [markdown]
# ### Operations on text data using NLTK.
# #### Tokenization:
# * Tokenization refers to break down the text into smaller units.
# * It splits paragraphs into sentences and sentences into words.
# * It is one of the initial steps of any NLP pipeline.

# %% [markdown]
# ### Word Tokenization
# * Process of breaking of sentence into smaller pieces.
# * It involves breaking down the text into words.

# %%
from nltk.tokenize import word_tokenize
word_tokenize("I like Python courses.")
# Out:
# ['I', 'like', 'Python', 'courses', '.']

# %% [markdown]
# ### Sentence Tokenization
# * Process of breaking of sentence
# * It involves breaking down the text into individual sentences.

# %%
from nltk.tokenize import sent_tokenize
sentence = "I love ice cream. I also like steak."
sent_tokenize(sentence)
# Out:
# ['I love ice cream.', 'I also like steak.']

# %%
from nltk.tokenize import sent_tokenize
para = "Thanks for taking my course. You guys rock. Learning is fun. Please take the rest of my course."
sent_tokenize(para)
# Out:
# ['Thanks for taking my course.',
#  'You guys rock.',
#  'Learning is fun.',
#  'Please take the rest of my course.']

# %% [markdown]
# ##### Paragraph Tokenizer

# %%
from nltk.tokenize import word_tokenize
para = "Thanks for taking my course. You guys rock. Learning is fun. Please take the rest of my course."
word_tokenize(para)
# Out:
# ['Thanks',
#  'for',
#  'taking',
#  'my',
#  'course',
#  '.',
#  'You',
#  'guys',
#  'rock',
#  '.',
#  'Learning',
#  'is',
#  'fun',
#  '.',
#  'Please',
#  'take',
#  'the',
#  'rest',
#  'of',
#  'my',
#  'course',
#  '.']

# %% [markdown]
# ##### Get  English stop words
# * The most frequent words in a language, such as articles, pronouns, prepositions, and conjunctions.

# %%
from nltk.corpus import stopwords
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))

# %%
print(len(stopWords))
print(stopWords)
# Out:
# 179
# ...

# %% [markdown]
# ### Store words & sentence into an array

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
 
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
phrases = sent_tokenize(data)
words = word_tokenize(data)

print(phrases)
print(words)
# Out:
# ['All work and no play makes jack dull boy.', 'All work and no play makes jack a dull boy.']
# ['All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'dull', 'boy', '.', 'All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', '.']

# %% [markdown]
# ### Remove stop words
# * Text may contain stop words like ‘the’, ‘is’, ‘are’. Stop words can be filtered from the text to be processed

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
 
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."

words = word_tokenize(data)
print(words)
# Out:
# ['All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'dull', 'boy', '.', 'All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
 
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
stopWords = set(stopwords.words('english'))
words = word_tokenize(data)
wordsFiltered = []
 
# Create a new list called wordsFiltered which contains all words which are not stop words.
for w in words:
    if w not in stopWords:
        wordsFiltered.append(w)
 
print(wordsFiltered)
# Out:
# ['All', 'work', 'play', 'makes', 'jack', 'dull', 'boy', '.', 'All', 'work', 'play', 'makes', 'jack', 'dull', 'boy', '.']

# %% [markdown]
# ### Stemming and Lemmatization
# * To reduce words to their root or base form.

# %% [markdown]
# ### Stemming

# %% [markdown]
# * A word stem is part of a word.
# * Stemming is the process of reducing a word to its roots of words known as a lemma.
# * It is sort of a normalization idea, but linguistic.
# * For example, the stem of the word waiting is wait.
# * PorterStremmer is most common algorithm for stemming

# %%
# Example:
from nltk.stem import PorterStemmer

# create an object of class PorterStemmer
porter = PorterStemmer()
print(porter.stem("play"))
print(porter.stem("playing"))
print(porter.stem("plays"))
print(porter.stem("played"))
# Out:
# play
# play
# play
# play

# %% [markdown]
# ##### Word Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
 
words = ["game","gaming","gamed","games"]
ps = PorterStemmer()
 
for word in words:
    print(ps.stem(word))
# Out:
# game
# game
# game
# game

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
 
ps = PorterStemmer()
 
sentence = "gaming, the gamers play games"
words = word_tokenize(sentence)
 
for word in words:
    print(word + ":" + ps.stem(word))
# Out:
# gaming:game
# ,:,
# the:the
# gamers:gamer
# play:play
# games:game

# %% [markdown]
# ### Lemmatization
# * Lemmatization involves grouping together the inflected forms of the same word.
# * We can reach out to the base form of any word which will be meaningful in nature. The base form here is called the Lemma.
# * Lemmatizers are slower and computationally more expensive than stemmers.

# %%
from nltk.stem import WordNetLemmatizer
# create an object of class WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("plays", 'v'))
print(lemmatizer.lemmatize("played", 'v'))
print(lemmatizer.lemmatize("play", 'v'))
print(lemmatizer.lemmatize("playing", 'v'))
# Out:
# play
# play
# play
# play

# %% [markdown]
# ### Part of Speech Tagging
# * Part of Speech (POS) tagging refers to assigning each word of a sentence to its part of speech.

# %% [markdown]
# ### Speech tagging

# %% [markdown]
# * Can automatically tag the parts of speech.
# * Given a sentence or paragraph, it can label words such as verbs, nouns and so on

# %%
from nltk import pos_tag
from nltk import word_tokenize

text = "Programming is fun"
tokenized_text = word_tokenize(text)
tags = tokens_tag = pos_tag(tokenized_text)
tags
# Out:
# [('Programming', 'VBG'), ('is', 'VBZ'), ('fun', 'NN')]

# %%
import nltk
from nltk.tokenize import PunktSentenceTokenizer
 
document = 'Whether you\'re new to programming or an experienced developer, it\'s easy to learn and use Python.'
sentences = nltk.sent_tokenize(document)   
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('Whether', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('new', 'JJ'), ('to', 'TO'), ('programming', 'VBG'), ('or', 'CC'), ('an', 'DT'), ('experienced', 'JJ'), ('developer', 'NN'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('easy', 'JJ'), ('to', 'TO'), ('learn', 'VB'), ('and', 'CC'), ('use', 'VB'), ('Python', 'NNP'), ('.', '.')]

# %% [markdown]
# ###### We can filter this data based on the type of word:

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
 
document = 'Today the Netherlands celebrates King\'s Day. To honor this tradition, the Dutch embassy in San Francisco invited me to'
sentences = nltk.sent_tokenize(document)   
 
data = []
for sent in sentences:
    data = data + nltk.pos_tag(nltk.word_tokenize(sent))
 
for word in data: 
    if 'NNP' in word[1]: 
        print(word)
# Out:
# ('Netherlands', 'NNP')
# ('King', 'NNP')
# ('Day', 'NNP')
# ('San', 'NNP')
# ('Francisco', 'NNP')

# %% [markdown]
# ##### Natural language processing to make prediction

# %% [markdown]
# * Given a name, the classifier will predict if it’s a male or female.
#
# * To create our analysis program, we have several steps:
#
#    * Data preparation
#    * Feature extraction
#    * Training
#    * Prediction

# %%
### Data preparation Dataset is simply a collection of tuples

import nltk.classify.util
from nltk.corpus import names

# Features (last letters) are extracted using:
def gender_features(word): 
    return {'last_letter': word[-1]}

# Load data and training 
names = ([(name, 'male') for name in names.words('male.txt')] + 
	 [(name, 'female') for name in names.words('female.txt')])

### Feature extraction
# Based on the dataset, we prepare our feature. The feature we will use  here is the last letter of a name.

featuresets = [(gender_features(n), g) for (n,g) in names]
train_set = featuresets

### Training & Prediction
# Trainig 
from nltk.classify import NaiveBayesClassifier
classifier = nltk.NaiveBayesClassifier.train(train_set) 
 
# Predict
#print(classifier.classify(gender_features('Frank')))

# Predict
name = input("Name: ")
print(classifier.classify(gender_features(name)))
# Out:
# Name:  Rahul
# male

# %% [markdown]
# ### For more: https://www.nltk.org/
